# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Importing data
path = Path('Resources/Spotify_Song_Attributes.csv')
df = pd.read_csv(path)

df.head()
# Out:
#                                            trackName  \
# 0                                           "Honest"
# 1  "In The Hall Of The Mountain King" from Peer G...
# 2                                 #BrooklynBloodPop!
# 3                                                $10
# 4                         (I Just) Died In Your Arms
#
#                   artistName  msPlayed              genre  danceability  \
# 0               Nico Collins    191772                NaN         0.476
# 1  London Symphony Orchestra   1806234  british orchestra         0.475
# 2                       SyKo    145610         glitchcore         0.691
# 3               Good Morning     25058   experimental pop         0.624
# 4               Cutting Crew   5504949         album rock         0.625
#
#    energy   key  loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0   0.799   4.0    -4.939   0.0       0.2120  ...    0.2570    0.577  162.139
# ...

# %%
# Checking value counts for id column
df['id'].value_counts()
# Out:
# id
# 2Pzhx26KqgTTKnko0uC7F7    4
# 500mvzh7TRZ0YdnVeHhj8b    4
# 5nujrmhLynf4yMoMtj8AQF    4
# 0mBP9X2gPCuapvpZ7TGDk3    4
# 3F7bhRhNpY4YKrwa4kGeUz    4
#                          ..
# 09HCvtlxNRpifu8jG1NRWk    2
# 0gGwIl6b1PRp2bE9wCbWa3    2
# 7k7JKDjCd9zuL0iF7iWaNs    2
# 3ze5haYQIPLiNHq3Iahz98    2
# 3BcN2Pcy0kTG1zm8Tz9MsB    2
# Name: count, Length: 4736, dtype: int64

# %%
# Dropping duplicate songs
df.drop_duplicates(subset=['id'],inplace=True)

# %%
# Checking that duplicates were dropped 
df['id'].value_counts()
# Out:
# id
# 7dTxqsaFGHOXwtzHINjfHv    1
# 3ri4y4r1BFc9YiPNgFXeGW    1
# 2zhPy8zbBf53XgTtkEbnbO    1
# 79npfYK6N5RnBc1jiaoHCr    1
# 55H02yyv7Vad1LFg3kmnVB    1
#                          ..
# 0LlTn7ZnC0Nu3lDY2cg8jL    1
# 7JIIY2oDPFkURYMCLJuzhe    1
# 6lGuFStXhrgBEap91aqGbs    1
# 6kiauSlWtddVQx4JwJx51p    1
# 3BcN2Pcy0kTG1zm8Tz9MsB    1
# Name: count, Length: 4736, dtype: int64

# %%
# Dropping irrelevant columns
df.drop(columns=['trackName','artistName','type','id','uri','track_href','analysis_url','msPlayed','duration_ms'],inplace=True)

# %%
# Checking for nulls 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4737 entries, 0 to 5039
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genre             4261 non-null   object
#  1   danceability      4736 non-null   float64
#  2   energy            4736 non-null   float64
#  3   key               4736 non-null   float64
#  4   loudness          4736 non-null   float64
#  5   mode              4736 non-null   float64
#  6   speechiness       4736 non-null   float64
#  7   acousticness      4736 non-null   float64
#  8   instrumentalness  4736 non-null   float64
#  9   liveness          4736 non-null   float64
#  10  valence           4736 non-null   float64
#  11  tempo             4736 non-null   float64
#  12  time_signature    4736 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 518.1+ KB

# %%
# Dropping nulls
df.dropna(inplace=True)

# %%
# Value count on genre
df['genre'].value_counts()[:10]
# Out:
# genre
# alt z                    327
# pop                      298
# filmi                    205
# dance pop                 84
# singer-songwriter pop     81
# alternative metal         74
# anime lo-fi               66
# art pop                   63
# drift phonk               62
# brostep                   58
# Name: count, dtype: int64

# %%
# Viewing progress
df.head()
# Out:
#                genre  danceability  energy   key  loudness  mode  speechiness  \
# 1  british orchestra         0.475   0.130   7.0   -17.719   1.0       0.0510
# 2         glitchcore         0.691   0.814   1.0    -3.788   0.0       0.1170
# 3   experimental pop         0.624   0.596   4.0    -9.804   1.0       0.0314
# 4         album rock         0.625   0.726  11.0   -11.402   0.0       0.0444
# 5              alt z         0.645   0.611   8.0    -5.925   0.0       0.1370
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 1        0.9160          0.956000    0.1010    0.122  112.241             4.0
# 2        0.0164          0.000000    0.3660    0.509  132.012             4.0
# 3        0.4750          0.203000    0.1190    0.896  120.969             4.0
# 4        0.0158          0.000169    0.0625    0.507  124.945             4.0
# 5        0.2900          0.000021    0.2370    0.645  157.475             3.0

# %%
# begin pca stuff
from sklearn.decomposition import PCA

# %%
# more dependencies
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# drop genre for pca
pca_df = df.drop(columns = ['genre'])

# %%
pca_df.head()
# Out:
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 1         0.475   0.130   7.0   -17.719   1.0       0.0510        0.9160
# 2         0.691   0.814   1.0    -3.788   0.0       0.1170        0.0164
# 3         0.624   0.596   4.0    -9.804   1.0       0.0314        0.4750
# 4         0.625   0.726  11.0   -11.402   0.0       0.0444        0.0158
# 5         0.645   0.611   8.0    -5.925   0.0       0.1370        0.2900
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 1          0.956000    0.1010    0.122  112.241             4.0
# 2          0.000000    0.3660    0.509  132.012             4.0
# 3          0.203000    0.1190    0.896  120.969             4.0
# 4          0.000169    0.0625    0.507  124.945             4.0
# 5          0.000021    0.2370    0.645  157.475             3.0

# %%
# Instantiate the PCA instance and declare the number of PCA variables
pca = PCA(n_components=2)

# %%
# Fit the PCA model on the transformed credit card DataFrame
df_pca = pca.fit_transform(pca_df)

# Review the first 5 rows of list data
df_pca[:5]
# Out:
# array([[  7.21729749,   8.94900459],
#        [-13.01325964,  -4.35646029],
#        [ -1.77454733,   1.28718206],
#        [ -5.70136708,   2.97644244],
#        [-38.39506021,  -1.34629456]])

# %%
 # Calculate the PCA explained variance ratio
amountdata_explained = pca.explained_variance_ratio_

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.
print(f"PCA info: {amountdata_explained}")
print(f"Explained Variance: {sum(amountdata_explained)}")
# Out:
# PCA info: [0.95361265 0.03119509]
# Explained Variance: 0.9848077452387086

# %%
 # Create the PCA DataFrame
song_pca_df = pd.DataFrame(
    df_pca,
    columns=["PCA1", "PCA2"]
)

# Review the PCA DataFrame
song_pca_df.head()
# Out:
#         PCA1      PCA2
# 0   7.217297  8.949005
# 1 -13.013260 -4.356460
# 2  -1.774547  1.287182
# 3  -5.701367  2.976442
# 4 -38.395060 -1.346295

# %%
# elbow method with pca

# Create a a list to store inertia values and the values of k
inertia = []
k = list(range(1, 11))

# Append the value of the computed inertia from the `inertia_` attribute of teh KMeans model instance
for i in k:
    k_model = KMeans(n_clusters=i, random_state=42)
    k_model.fit(song_pca_df)
    inertia.append(k_model.inertia_)

# Define a DataFrame to hold the values for k and the corresponding inertia
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

# Review the DataFrame
df_elbow.head()
# Out:
#    k       inertia
# 0  1  3.703264e+06
# 1  2  1.387640e+06
# 2  3  7.081196e+05
# 3  4  4.930505e+05
# 4  5  3.453169e+05

# %%
 # Plot the Elbow Curve
df_elbow.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %%
# Define the model with 3 clusters
model = KMeans(n_clusters=3, random_state=42)

# Fit the model
model.fit(song_pca_df)

# Make predictions
k_3 = model.predict(song_pca_df)

# Create a copy of the PCA DataFrame
song_pca_predictions_df = song_pca_df.copy()

# Add a class column with the labels
song_pca_predictions_df["predictions"] = k_3

# %%
# Plot the clusters
song_pca_predictions_df.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="predictions"
)
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PCA1]   (PCA2)

# %%
# Define the model with 3 clusters
model = KMeans(n_clusters=4, random_state=42)

# Fit the model
model.fit(song_pca_df)

# Make predictions
k_4 = model.predict(song_pca_df)

# Create a copy of the PCA DataFrame
song_pca_predictions_df = song_pca_df.copy()

# Add a class column with the labels
song_pca_predictions_df["predictions"] = k_4

# %%
# Plot the clusters
song_pca_predictions_df.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="predictions"
)
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PCA1]   (PCA2)

# %%
# Define the model with 3 clusters
model = KMeans(n_clusters=5, random_state=42)

# Fit the model
model.fit(song_pca_df)

# Make predictions
k_5 = model.predict(song_pca_df)

# Create a copy of the PCA DataFrame
song_pca_predictions_df = song_pca_df.copy()

# Add a class column with the labels
song_pca_predictions_df["predictions"] = k_5

# %%
# Plot the clusters
song_pca_predictions_df.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="predictions"
)
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PCA1]   (PCA2)

# %%
# Define the model with 3 clusters
model = KMeans(n_clusters=6, random_state=42)

# Fit the model
model.fit(song_pca_df)

# Make predictions
k_6 = model.predict(song_pca_df)

# Create a copy of the PCA DataFrame
song_pca_predictions_df = song_pca_df.copy()

# Add a class column with the labels
song_pca_predictions_df["predictions"] = k_6

# %%
# Plot the clusters
song_pca_predictions_df.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="predictions"
)
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PCA1]   (PCA2)

# %%
# Define the model with 3 clusters
model = KMeans(n_clusters=7, random_state=42)

# Fit the model
model.fit(song_pca_df)

# Make predictions
k_7 = model.predict(song_pca_df)

# Create a copy of the PCA DataFrame
song_pca_predictions_df = song_pca_df.copy()

# Add a class column with the labels
song_pca_predictions_df["predictions"] = k_7

# %%
# Plot the clusters
song_pca_predictions_df.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="predictions"
)
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PCA1]   (PCA2)
