# %%
# Dependencies
import pandas as pd
from pathlib import Path

# begin pca stuff
from sklearn.decomposition import PCA
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a9b17431-000a-4b69-a6d1-38e85f27f967" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7553f876-8faa-45b9-991a-f08c5f23f4bf":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"7dc79fd8b6e448378f202dde5e25b9b7","client_comm_id":"b742f9fca3734785804cd4313fda879f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"7553f876-8faa-45b9-991a-f08c5f23f4bf","roots":{"p1002":"a9b17431-000a-4b69-a6d1-38e85f27f967"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Importing data
path = Path('Resources/Spotify_Song_Attributes.csv')
df = pd.read_csv(path)

# %%
# Dropping irrelevant columns
df.drop(columns=['type','uri','track_href','analysis_url','msPlayed','duration_ms'],inplace=True)

# %%
# Dropping nulls
df.dropna(inplace=True)

# %%
# Value count on genre
df['genre'].value_counts()[:10]
# Out:
# genre
# alt z                    656
# pop                      602
# filmi                    412
# dance pop                172
# singer-songwriter pop    164
# alternative metal        150
# anime lo-fi              136
# art pop                  126
# drift phonk              124
# brostep                  116
# Name: count, dtype: int64

# %%
number_genres = df['genre'].nunique()
number_genres
# Out:
# 523

# %%
df.head()
# Out:
#                                            trackName  \
# 1  "In The Hall Of The Mountain King" from Peer G...
# 2                                 #BrooklynBloodPop!
# 3                                                $10
# 4                         (I Just) Died In Your Arms
# 5                                      (L)only Child
#
#                   artistName              genre  danceability  energy   key  \
# 1  London Symphony Orchestra  british orchestra         0.475   0.130   7.0
# 2                       SyKo         glitchcore         0.691   0.814   1.0
# 3               Good Morning   experimental pop         0.624   0.596   4.0
# 4               Cutting Crew         album rock         0.625   0.726  11.0
# 5                salem ilese              alt z         0.645   0.611   8.0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 1   -17.719   1.0       0.0510        0.9160          0.956000    0.1010
# 2    -3.788   0.0       0.1170        0.0164          0.000000    0.3660
# 3    -9.804   1.0       0.0314        0.4750          0.203000    0.1190
# 4   -11.402   0.0       0.0444        0.0158          0.000169    0.0625
# 5    -5.925   0.0       0.1370        0.2900          0.000021    0.2370
#
#    valence    tempo                      id  time_signature
# 1    0.122  112.241  14Qcrx6Dfjvcj0H8oV8oUW             4.0
# 2    0.509  132.012  7K9Z3yFNNLv5kwTjQYGjnu             4.0
# 3    0.896  120.969  3koAwrM1RO0TGMeQJ3qt9J             4.0
# 4    0.507  124.945  4ByEFOBuLXpCqvO1kw8Wdm             4.0
# 5    0.645  157.475  22lJaG2yxlSjIwdUIddcFk             3.0

# %%
pca_df_to_work_with = df.drop(columns=['trackName', 'artistName', 'id','time_signature'])
pca_df_to_work_with.head()
# Out:
#                genre  danceability  energy   key  loudness  mode  speechiness  \
# 1  british orchestra         0.475   0.130   7.0   -17.719   1.0       0.0510
# 2         glitchcore         0.691   0.814   1.0    -3.788   0.0       0.1170
# 3   experimental pop         0.624   0.596   4.0    -9.804   1.0       0.0314
# 4         album rock         0.625   0.726  11.0   -11.402   0.0       0.0444
# 5              alt z         0.645   0.611   8.0    -5.925   0.0       0.1370
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 1        0.9160          0.956000    0.1010    0.122  112.241
# 2        0.0164          0.000000    0.3660    0.509  132.012
# 3        0.4750          0.203000    0.1190    0.896  120.969
# 4        0.0158          0.000169    0.0625    0.507  124.945
# 5        0.2900          0.000021    0.2370    0.645  157.475

# %%
# Geeks for Geeks; sidgautam
top_15 = pca_df_to_work_with['genre'].value_counts().head(15) 
top_15 = top_15.keys()
top_15.tolist()
# Out:
# ['alt z',
#  'pop',
#  'filmi',
#  'dance pop',
#  'singer-songwriter pop',
#  'alternative metal',
#  'anime lo-fi',
#  'art pop',
#  'drift phonk',
#  'brostep',
#  'modern alternative rock',
#  'lo-fi study',
#  'edm',
#  'anime',
#  'chill pop']

# %%
# Saturn Cloud
mask = pca_df_to_work_with['genre'].isin(top_15)
mask
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5         True
#          ...
# 10074     True
# 10075    False
# 10077    False
# 10078     True
# 10079    False
# Name: genre, Length: 8580, dtype: bool

# %%
#Saturn Cloud
pca_df_to_work_with2 = pca_df_to_work_with[mask]
pca_df_to_work_with2
# Out:
#                        genre  danceability  energy   key  loudness  mode  \
# 5                      alt z         0.645   0.611   8.0    -5.925   0.0
# 9                  dance pop         0.759   0.699   0.0    -5.745   0.0
# 14     singer-songwriter pop         0.830   0.414   3.0    -7.387   1.0
# 16     singer-songwriter pop         0.459   0.214   5.0   -10.660   1.0
# 17                     alt z         0.639   0.724   7.0    -6.346   1.0
# ...                      ...           ...     ...   ...       ...   ...
# 10069                art pop         0.324   0.416  11.0    -8.920   0.0
# 10070                    pop         0.799   0.539   1.0    -6.351   1.0
# 10073                    pop         0.784   0.845   3.0    -2.793   1.0
# 10074                  alt z         0.745   0.477  11.0    -7.706   0.0
# 10078                art pop         0.632   0.284   9.0   -14.025   0.0
#
#        speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 5           0.1370         0.290          0.000021     0.237    0.645  157.475
# 9           0.0307         0.202          0.000131     0.443    0.907   92.960
# 14          0.1480         0.497          0.000000     0.187    0.797   87.990
# 16          0.0403         0.634          0.000000     0.125    0.397  163.816
# 17          0.0664         0.452          0.000000     0.159    0.522  129.712
# ...            ...           ...               ...       ...      ...      ...
# 10069       0.0368         0.262          0.000037     0.110    0.151  113.986
# 10070       0.0421         0.199          0.000017     0.165    0.394  136.948
# 10073       0.0596         0.286          0.000016     0.074    0.888  105.981
# 10074       0.0880         0.202          0.000000     0.120    0.454  136.055
# 10078       0.0801         0.932          0.000476     0.233    0.208  129.642
#
# [3172 rows x 12 columns]

# %%
pca_df2 = pca_df_to_work_with2.set_index('genre')
pca_df2
# Out:
#                        danceability  energy   key  loudness  mode  \
# genre
# alt z                         0.645   0.611   8.0    -5.925   0.0
# dance pop                     0.759   0.699   0.0    -5.745   0.0
# singer-songwriter pop         0.830   0.414   3.0    -7.387   1.0
# singer-songwriter pop         0.459   0.214   5.0   -10.660   1.0
# alt z                         0.639   0.724   7.0    -6.346   1.0
# ...                             ...     ...   ...       ...   ...
# art pop                       0.324   0.416  11.0    -8.920   0.0
# pop                           0.799   0.539   1.0    -6.351   1.0
# pop                           0.784   0.845   3.0    -2.793   1.0
# alt z                         0.745   0.477  11.0    -7.706   0.0
# art pop                       0.632   0.284   9.0   -14.025   0.0
#
#                        speechiness  acousticness  instrumentalness  liveness  \
# genre
# alt z                       0.1370         0.290          0.000021     0.237
# dance pop                   0.0307         0.202          0.000131     0.443
# singer-songwriter pop       0.1480         0.497          0.000000     0.187
# singer-songwriter pop       0.0403         0.634          0.000000     0.125
# alt z                       0.0664         0.452          0.000000     0.159
# ...                            ...           ...               ...       ...
# art pop                     0.0368         0.262          0.000037     0.110
# pop                         0.0421         0.199          0.000017     0.165
# pop                         0.0596         0.286          0.000016     0.074
# alt z                       0.0880         0.202          0.000000     0.120
# art pop                     0.0801         0.932          0.000476     0.233
#
#                        valence    tempo
# genre
# alt z                    0.645  157.475
# dance pop                0.907   92.960
# singer-songwriter pop    0.797   87.990
# singer-songwriter pop    0.397  163.816
# alt z                    0.522  129.712
# ...                        ...      ...
# art pop                  0.151  113.986
# pop                      0.394  136.948
# pop                      0.888  105.981
# alt z                    0.454  136.055
# art pop                  0.208  129.642
#
# [3172 rows x 11 columns]

# %%
pca_df_to_work_with["genre"].value_counts()
# Out:
# genre
# alt z                         656
# pop                           602
# filmi                         412
# dance pop                     172
# singer-songwriter pop         164
#                              ...
# children's folk                 2
# detroit indie                   2
# celtic rock                     2
# electro                         2
# australian alternative pop      2
# Name: count, Length: 523, dtype: int64

# %%
pca_df = pca_df_to_work_with.set_index("genre")
pca_df.head()
# Out:
#                    danceability  energy   key  loudness  mode  speechiness  \
# genre
# british orchestra         0.475   0.130   7.0   -17.719   1.0       0.0510
# glitchcore                0.691   0.814   1.0    -3.788   0.0       0.1170
# experimental pop          0.624   0.596   4.0    -9.804   1.0       0.0314
# album rock                0.625   0.726  11.0   -11.402   0.0       0.0444
# alt z                     0.645   0.611   8.0    -5.925   0.0       0.1370
#
#                    acousticness  instrumentalness  liveness  valence    tempo
# genre
# british orchestra        0.9160          0.956000    0.1010    0.122  112.241
# glitchcore               0.0164          0.000000    0.3660    0.509  132.012
# experimental pop         0.4750          0.203000    0.1190    0.896  120.969
# album rock               0.0158          0.000169    0.0625    0.507  124.945
# alt z                    0.2900          0.000021    0.2370    0.645  157.475

# %%
# Instantiate the PCA instance and declare the number of PCA variables
pca = PCA(n_components=3)

# %%
df_pca2 = pca.fit_transform(pca_df2)
df_pca2[:5]
# Out:
# array([[-39.08089811,  -0.73119004,   2.73493545],
#        [ 25.3874272 ,  -3.10281663,  -5.28923631],
#        [ 30.41331592,  -1.68886937,  -2.27139648],
#        [-45.24323129,   4.31530579,  -0.17502281],
#        [-11.32081254,  -1.30015066,   1.71948748]])

# %%
amountdata_explained2 = pca.explained_variance_ratio_
amountdata_explained2
# Out:
# array([0.95615071, 0.02838129, 0.01492738])

# %%
# Fit the PCA model on the transformed credit card DataFrame
df_pca = pca.fit_transform(pca_df)

# Review the first 5 rows of list data
df_pca[:5]
# Out:
# array([[  7.21235966,   8.94620249,   1.77528275],
#        [-13.02052186,  -4.35497414,  -4.2571762 ],
#        [ -1.78084845,   1.28612518,  -1.25047078],
#        [ -5.70759488,   2.97511995,   5.76714394],
#        [-38.40171827,  -1.35399245,   2.72496699]])

# %%
 # Calculate the PCA explained variance ratio
amountdata_explained = pca.explained_variance_ratio_
amountdata_explained
# Out:
# array([0.95365023, 0.03129739, 0.01451048])

# %%
# sum of variance accounted for
print(f"PCA info: {amountdata_explained}")
print(f"Explained Variance: {sum(amountdata_explained)}")
# Out:
# PCA info: [0.95365023 0.03129739 0.01451048]
# Explained Variance: 0.9994580988691859

# %%
song_pca_df2 = pd.DataFrame(
    df_pca2,
    columns = ['PCA1','PCA2','PCA3']
)

# %%
 # Create the PCA DataFrame
song_pca_df = pd.DataFrame(
    df_pca,
    columns=["PCA1", "PCA2", "PCA3"]
)

# %%
song_pca_df2.head()
# Out:
#         PCA1      PCA2      PCA3
# 0 -39.080898 -0.731190  2.734935
# 1  25.387427 -3.102817 -5.289236
# 2  30.413316 -1.688869 -2.271396
# 3 -45.243231  4.315306 -0.175023
# 4 -11.320813 -1.300151  1.719487

# %%
song_pca_df.head()
# Out:
#         PCA1      PCA2      PCA3
# 0   7.212360  8.946202  1.775283
# 1 -13.020522 -4.354974 -4.257176
# 2  -1.780848  1.286125 -1.250471
# 3  -5.707595  2.975120  5.767144
# 4 -38.401718 -1.353992  2.724967

# %%
song_pca_df2.drop(columns=["PCA3"], inplace=True)
song_pca_df2.head()
# Out:
#         PCA1      PCA2
# 0 -39.080898 -0.731190
# 1  25.387427 -3.102817
# 2  30.413316 -1.688869
# 3 -45.243231  4.315306
# 4 -11.320813 -1.300151

# %%
song_pca_df.drop(columns=["PCA3"], inplace=True)
song_pca_df.head()
# Out:
#         PCA1      PCA2
# 0   7.212360  8.946202
# 1 -13.020522 -4.354974
# 2  -1.780848  1.286125
# 3  -5.707595  2.975120
# 4 -38.401718 -1.353992

# %%
pca_with_genre2 = pd.concat([pca_df_to_work_with2, song_pca_df2], axis="columns")[["genre", "PCA1", "PCA2"]].set_index("genre")
pca_with_genre2.head()
# Out:
#                             PCA1      PCA2
# genre
# alt z                   4.387375 -2.479845
# dance pop             -25.564251  0.132000
# singer-songwriter pop  23.339888 -3.261445
# singer-songwriter pop  23.296996 -2.983431
# alt z                 -23.604580 -1.587518

# %%
pca_with_genre = pd.concat([pca_df_to_work_with, song_pca_df], axis="columns")[["genre", "PCA1", "PCA2"]].set_index("genre")
pca_with_genre.head()
# Out:
#                         PCA1      PCA2
# genre
# british orchestra -13.020522 -4.354974
# glitchcore         -1.780848  1.286125
# experimental pop   -5.707595  2.975120
# album rock        -38.401718 -1.353992
# alt z               0.984533 -3.926671

# %%
pca_with_genre_index2 = pca_with_genre2.index.tolist()
pca_with_genre_index2
# Out:
# ['alt z',
#  'dance pop',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'alt z',
#  'alt z',
#  'alternative metal',
#  'pop',
#  'pop',
#  'singer-songwriter pop',
#  'modern alternative rock',
#  'pop',
#  'singer-songwriter pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'pop',
#  'filmi',
#  'art pop',
#  'alt z',
#  'singer-songwriter pop',
#  'alt z',
#  'alt z',
#  'pop',
#  'alt z',
#  'alt z',
#  'pop',
#  'art pop',
#  'edm',
#  'alt z',
#  'alt z',
#  'alternative metal',
#  'lo-fi study',
#  'pop',
#  'pop',
#  'singer-songwriter pop',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'pop',
#  'lo-fi study',
#  'alt z',
#  'chill pop',
#  'filmi',
#  'modern alternative rock',
#  'brostep',
#  'anime',
#  'pop',
#  'alt z',
#  'singer-songwriter pop',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'pop',
#  'pop',
#  'alternative metal',
#  'brostep',
#  'dance pop',
#  'brostep',
#  'brostep',
#  'art pop',
#  'alt z',
#  'pop',
#  'dance pop',
#  'pop',
#  'pop',
#  'filmi',
#  'filmi',
#  'anime lo-fi',
#  'anime lo-fi',
#  'filmi',
#  'pop',
#  'filmi',
#  'brostep',
#  'pop',
#  'alternative metal',
#  'filmi',
#  'filmi',
#  'alt z',
#  'chill pop',
#  'dance pop',
#  'anime',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'alt z',
#  'filmi',
#  'alt z',
#  'lo-fi study',
#  'lo-fi study',
#  'anime lo-fi',
#  'pop',
#  'anime lo-fi',
#  'singer-songwriter pop',
#  'anime',
#  'drift phonk',
#  'drift phonk',
#  'pop',
#  'drift phonk',
#  'anime',
#  'alternative metal',
#  'filmi',
#  'edm',
#  'alt z',
#  'singer-songwriter pop',
#  'chill pop',
#  'alt z',
#  'pop',
#  'pop',
#  'pop',
#  'art pop',
#  'pop',
#  'filmi',
#  'dance pop',
#  'dance pop',
#  'filmi',
#  'brostep',
#  'filmi',
#  'modern alternative rock',
#  'modern alternative rock',
#  'edm',
#  'edm',
#  'dance pop',
#  'pop',
#  'alt z',
#  'filmi',
#  'pop',
#  'alternative metal',
#  'pop',
#  'alt z',
#  'singer-songwriter pop',
#  'pop',
#  'brostep',
#  'pop',
#  'pop',
#  'lo-fi study',
#  'filmi',
#  'filmi',
#  'filmi',
#  'pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'anime',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'alternative metal',
#  'alternative metal',
#  'alternative metal',
#  'singer-songwriter pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'alt z',
#  'pop',
#  'alt z',
#  'alt z',
#  'singer-songwriter pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'singer-songwriter pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'chill pop',
#  'alt z',
#  'lo-fi study',
#  'alt z',
#  'singer-songwriter pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'chill pop',
#  'anime lo-fi',
#  'pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'anime lo-fi',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'pop',
#  'pop',
#  'singer-songwriter pop',
#  'pop',
#  'lo-fi study',
#  'alt z',
#  'singer-songwriter pop',
#  'alt z',
#  'pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'alt z',
#  'dance pop',
#  'singer-songwriter pop',
#  'alt z',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'alt z',
#  'anime lo-fi',
#  'singer-songwriter pop',
#  'alt z',
#  'alt z',
#  'anime lo-fi',
#  'alt z',
#  'art pop',
#  'pop',
#  'alt z',
#  'pop',
#  'lo-fi study',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'anime lo-fi',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'pop',
#  'alt z',
#  'pop',
#  'anime lo-fi',
#  'pop',
#  'alt z',
#  'pop',
#  'singer-songwriter pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'chill pop',
#  'pop',
#  'alt z',
#  'pop',
#  'alt z',
#  'pop',
#  'alt z',
#  'chill pop',
#  'alt z',
#  'alt z',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'drift phonk',
#  'pop',
#  'alt z',
#  'singer-songwriter pop',
#  'drift phonk',
#  'drift phonk',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'art pop',
#  'alt z',
#  'pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'pop',
#  'alternative metal',
#  'alt z',
#  'edm',
#  'pop',
#  'modern alternative rock',
#  'anime lo-fi',
#  'anime lo-fi',
#  'filmi',
#  'alternative metal',
#  'pop',
#  'art pop',
#  'modern alternative rock',
#  'art pop',
#  'singer-songwriter pop',
#  'dance pop',
#  'alt z',
#  'pop',
#  'alt z',
#  'dance pop',
#  'alt z',
#  'alternative metal',
#  'brostep',
#  'lo-fi study',
#  'lo-fi study',
#  'chill pop',
#  'edm',
#  'singer-songwriter pop',
#  'anime',
#  'anime',
#  'anime',
#  'filmi',
#  'alternative metal',
#  'alternative metal',
#  'singer-songwriter pop',
#  'alternative metal',
#  'anime lo-fi',
#  'anime lo-fi',
#  'anime',
#  'alternative metal',
#  'pop',
#  'alt z',
#  'drift phonk',
#  'drift phonk',
#  'drift phonk',
#  'dance pop',
#  'pop',
#  'pop',
#  'alt z',
#  'pop',
#  'pop',
#  'alt z',
#  'filmi',
#  'filmi',
#  'dance pop',
#  'art pop',
#  'pop',
#  'alt z',
#  'dance pop',
#  'dance pop',
#  'pop',
#  'filmi',
#  'filmi',
#  'modern alternative rock',
#  'brostep',
#  'modern alternative rock',
#  'filmi',
#  'alternative metal',
#  'filmi',
#  'edm',
#  'singer-songwriter pop',
#  'pop',
#  'chill pop',
#  'edm',
#  'edm',
#  'lo-fi study',
#  'dance pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'brostep',
#  'brostep',
#  'dance pop',
#  'anime lo-fi',
#  'anime lo-fi',
#  'pop',
#  'alternative metal',
#  'alt z',
#  'art pop',
#  'pop',
#  'singer-songwriter pop',
#  'modern alternative rock',
#  'alternative metal',
#  'alt z',
#  'alt z',
#  'singer-songwriter pop',
#  'chill pop',
#  'edm',
#  'alt z',
#  'lo-fi study',
#  'dance pop',
#  'modern alternative rock',
#  'alt z',
#  'art pop',
#  'drift phonk',
#  'drift phonk',
#  'pop',
#  'drift phonk',
#  'drift phonk',
#  'pop',
#  'pop',
#  'modern alternative rock',
#  'alt z',
#  'alt z',
#  'alt z',
#  'dance pop',
#  'pop',
#  'alt z',
#  'anime lo-fi',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'art pop',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'pop',
#  'alt z',
#  'filmi',
#  'lo-fi study',
#  'lo-fi study',
#  'lo-fi study',
#  'art pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'art pop',
#  'art pop',
#  'art pop',
#  'filmi',
#  'alt z',
#  'alt z',
#  'drift phonk',
#  'alternative metal',
#  'filmi',
#  'alt z',
#  'edm',
#  'drift phonk',
#  'alt z',
#  'modern alternative rock',
#  'filmi',
#  'art pop',
#  'lo-fi study',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'alt z',
#  'drift phonk',
#  'lo-fi study',
#  'pop',
#  'lo-fi study',
#  'pop',
#  'dance pop',
#  'pop',
#  'brostep',
#  'brostep',
#  'pop',
#  'alt z',
#  'lo-fi study',
#  'alt z',
#  'anime lo-fi',
#  'edm',
#  'modern alternative rock',
#  'pop',
#  'lo-fi study',
#  'anime lo-fi',
#  'dance pop',
#  'alt z',
#  'pop',
#  'alt z',
#  'filmi',
#  'lo-fi study',
#  'modern alternative rock',
#  'dance pop',
#  'drift phonk',
#  'alt z',
#  'brostep',
#  'alternative metal',
#  'pop',
#  'dance pop',
#  'filmi',
#  'dance pop',
#  'filmi',
#  'edm',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'singer-songwriter pop',
#  'alternative metal',
#  'singer-songwriter pop',
#  'alternative metal',
#  'alt z',
#  'pop',
#  'singer-songwriter pop',
#  'art pop',
#  'drift phonk',
#  'drift phonk',
#  'anime',
#  'alt z',
#  'alternative metal',
#  'pop',
#  'modern alternative rock',
#  'alt z',
#  'alt z',
#  'singer-songwriter pop',
#  'alt z',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'edm',
#  'pop',
#  'singer-songwriter pop',
#  'filmi',
#  'pop',
#  'alt z',
#  'alt z',
#  'alternative metal',
#  'alternative metal',
#  'edm',
#  'pop',
#  'alt z',
#  'brostep',
#  'lo-fi study',
#  'chill pop',
#  'anime lo-fi',
#  'anime lo-fi',
#  'modern alternative rock',
#  'lo-fi study',
#  'brostep',
#  'edm',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'pop',
#  'alt z',
#  'alternative metal',
#  'singer-songwriter pop',
#  'alternative metal',
#  'alt z',
#  'filmi',
#  'drift phonk',
#  'alt z',
#  'alt z',
#  'pop',
#  'filmi',
#  'singer-songwriter pop',
#  'filmi',
#  'alt z',
#  'alt z',
#  'dance pop',
#  'anime lo-fi',
#  'anime lo-fi',
#  'pop',
#  'art pop',
#  'pop',
#  'alt z',
#  'lo-fi study',
#  'alternative metal',
#  'art pop',
#  'singer-songwriter pop',
#  'pop',
#  'chill pop',
#  'alt z',
#  'brostep',
#  'lo-fi study',
#  'alternative metal',
#  'pop',
#  'drift phonk',
#  'pop',
#  'pop',
#  'drift phonk',
#  'brostep',
#  'drift phonk',
#  'filmi',
#  'singer-songwriter pop',
#  'lo-fi study',
#  'filmi',
#  'alt z',
#  'alternative metal',
#  'pop',
#  'brostep',
#  'chill pop',
#  'art pop',
#  'dance pop',
#  'filmi',
#  'pop',
#  'alt z',
#  'dance pop',
#  'pop',
#  'art pop',
#  'alt z',
#  'edm',
#  'alt z',
#  'lo-fi study',
#  'dance pop',
#  'chill pop',
#  'alt z',
#  'pop',
#  'pop',
#  'dance pop',
#  'pop',
#  'pop',
#  'alt z',
#  'pop',
#  'chill pop',
#  'modern alternative rock',
#  'edm',
#  'alt z',
#  'alternative metal',
#  'modern alternative rock',
#  'singer-songwriter pop',
#  'alt z',
#  'modern alternative rock',
#  'brostep',
#  'alternative metal',
#  'pop',
#  'art pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'anime lo-fi',
#  'anime lo-fi',
#  'anime lo-fi',
#  'edm',
#  'edm',
#  'pop',
#  'singer-songwriter pop',
#  'alt z',
#  'filmi',
#  'alt z',
#  'drift phonk',
#  'drift phonk',
#  'alt z',
#  'singer-songwriter pop',
#  'pop',
#  'pop',
#  'lo-fi study',
#  'alternative metal',
#  'dance pop',
#  'filmi',
#  'alt z',
#  'pop',
#  'alt z',
#  'alt z',
#  'chill pop',
#  'pop',
#  'alt z',
#  'pop',
#  'alt z',
#  'pop',
#  'pop',
#  'alt z',
#  'anime lo-fi',
#  'anime lo-fi',
#  'pop',
#  'pop',
#  'dance pop',
#  'pop',
#  'pop',
#  'pop',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'pop',
#  'modern alternative rock',
#  'chill pop',
#  'chill pop',
#  'pop',
#  'pop',
#  'dance pop',
#  'singer-songwriter pop',
#  'art pop',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'pop',
#  'chill pop',
#  'alt z',
#  'drift phonk',
#  'brostep',
#  'singer-songwriter pop',
#  'alt z',
#  'dance pop',
#  'alt z',
#  'alternative metal',
#  'alt z',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'alt z',
#  'pop',
#  'singer-songwriter pop',
#  'alternative metal',
#  'chill pop',
#  'alt z',
#  'pop',
#  'alternative metal',
#  'anime lo-fi',
#  'alt z',
#  'alt z',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'pop',
#  'pop',
#  'chill pop',
#  'dance pop',
#  'chill pop',
#  'alt z',
#  'alt z',
#  'filmi',
#  'alt z',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'dance pop',
#  'alt z',
#  'filmi',
#  'anime lo-fi',
#  'alt z',
#  'art pop',
#  'pop',
#  'pop',
#  'edm',
#  'art pop',
#  'lo-fi study',
#  'art pop',
#  'alt z',
#  'dance pop',
#  'alt z',
#  'drift phonk',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'anime',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'alt z',
#  'alt z',
#  'drift phonk',
#  'filmi',
#  'filmi',
#  'filmi',
#  'pop',
#  'art pop',
#  'alt z',
#  'brostep',
#  'brostep',
#  'modern alternative rock',
#  'alternative metal',
#  'pop',
#  'filmi',
#  'chill pop',
#  'dance pop',
#  'alt z',
#  'pop',
#  'pop',
#  'filmi',
#  'anime',
#  'anime lo-fi',
#  'anime lo-fi',
#  'anime lo-fi',
#  'anime lo-fi',
#  'anime lo-fi',
#  'alternative metal',
#  'filmi',
#  'filmi',
#  'filmi',
#  'brostep',
#  'alternative metal',
#  'drift phonk',
#  'pop',
#  'alternative metal',
#  'alt z',
#  'alt z',
#  'alt z',
#  'art pop',
#  'filmi',
#  'lo-fi study',
#  'pop',
#  'filmi',
#  'anime lo-fi',
#  'lo-fi study',
#  'lo-fi study',
#  'dance pop',
#  'brostep',
#  'alternative metal',
#  'drift phonk',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'edm',
#  'edm',
#  'alt z',
#  'dance pop',
#  'edm',
#  'dance pop',
#  'dance pop',
#  'alt z',
#  'dance pop',
#  'dance pop',
#  'pop',
#  'pop',
#  'alt z',
#  'dance pop',
#  'alt z',
#  'art pop',
#  'pop',
#  'edm',
#  'drift phonk',
#  'pop',
#  'alt z',
#  'modern alternative rock',
#  'chill pop',
#  'anime lo-fi',
#  'anime lo-fi',
#  'chill pop',
#  'alternative metal',
#  'pop',
#  'lo-fi study',
#  'edm',
#  'pop',
#  'singer-songwriter pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'lo-fi study',
#  'modern alternative rock',
#  'pop',
#  'chill pop',
#  'chill pop',
#  'chill pop',
#  'brostep',
#  'pop',
#  'dance pop',
#  'singer-songwriter pop',
#  'dance pop',
#  'pop',
#  'pop',
#  'alt z',
#  'filmi',
#  'dance pop',
#  'alt z',
#  'filmi',
#  'chill pop',
#  'pop',
#  'pop',
#  'alt z',
#  'drift phonk',
#  'drift phonk',
#  'filmi',
#  'filmi',
#  'alt z',
#  'filmi',
#  'filmi',
#  'filmi',
#  'brostep',
#  'filmi',
#  'alt z',
#  'filmi',
#  'pop',
#  'pop',
#  'pop',
#  'alternative metal',
#  'anime lo-fi',
#  'anime lo-fi',
#  'pop',
#  'pop',
#  'drift phonk',
#  'filmi',
#  'filmi',
#  'alt z',
#  'filmi',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'pop',
#  'pop',
#  'alt z',
#  'dance pop',
#  'alt z',
#  'alt z',
#  'anime lo-fi',
#  'singer-songwriter pop',
#  'pop',
#  'alt z',
#  'lo-fi study',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'alt z',
#  'alt z',
#  'modern alternative rock',
#  'singer-songwriter pop',
#  'art pop',
#  'pop',
#  'filmi',
#  'edm',
#  'alt z',
#  'pop',
#  'pop',
#  'pop',
#  'filmi',
#  'filmi',
#  'pop',
#  'filmi',
#  'pop',
#  'modern alternative rock',
#  'alt z',
#  'chill pop',
#  'pop',
#  'alt z',
#  'singer-songwriter pop',
#  'alt z',
#  'alt z',
#  'chill pop',
#  'edm',
#  'alt z',
#  ...]

# %%
pca_with_genre_index = pca_with_genre.index.tolist()
pca_with_genre_index
# Out:
# ['british orchestra',
#  'glitchcore',
#  'experimental pop',
#  'album rock',
#  'alt z',
#  'guitar case',
#  'cloud rap',
#  'dance pop',
#  'desi hip hop',
#  'lo-fi sleep',
#  'contemporary country',
#  'bedroom r&b',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'alt z',
#  'la pop',
#  'lo-fi chill',
#  'alt z',
#  'orchestral soundtrack',
#  'glitchcore',
#  'comic',
#  'alternative metal',
#  'glitchcore',
#  'deep underground hip hop',
#  'pop',
#  'brooklyn drill',
#  'classical',
#  'american orchestra',
#  'classical',
#  'pop',
#  'singer-songwriter pop',
#  'modern alternative rock',
#  'pop',
#  'scandipop',
#  'alabama indie',
#  'singer-songwriter pop',
#  'stomp and holler',
#  'pop',
#  'anime score',
#  'pop',
#  'pop',
#  'pop',
#  'dfw rap',
#  'punjabi pop',
#  'folk-pop',
#  'acoustic pop',
#  'atl hip hop',
#  'pop',
#  'alt z',
#  'pop',
#  'filmi',
#  'art pop',
#  'japanese vgm',
#  'sleep',
#  'electronica',
#  'alt z',
#  'singer-songwriter pop',
#  'australian pop',
#  'danish pop',
#  'melodic rap',
#  'alt z',
#  'boy band',
#  'alt z',
#  'solipsynthm',
#  'pop',
#  'alt z',
#  'alt z',
#  'pop',
#  'ambient guitar',
#  'art pop',
#  'edm',
#  'bass house',
#  'orchestral soundtrack',
#  'alt z',
#  'alt z',
#  'alternative metal',
#  'show tunes',
#  'show tunes',
#  'chillwave',
#  'lo-fi study',
#  'post-teen pop',
#  'post-teen pop',
#  'german soundtrack',
#  'hollywood',
#  'gen z singer-songwriter',
#  'instrumental post-rock',
#  'pop',
#  'baroque pop',
#  'bass house',
#  'pop',
#  'r&b',
#  'singer-songwriter pop',
#  'bedroom pop',
#  'dark r&b',
#  'chill r&b',
#  'canadian contemporary r&b',
#  'aggressive phonk',
#  'aggressive phonk',
#  'aggressive phonk',
#  'hindi indie',
#  'himachali pop',
#  'odia bhajan',
#  'desi pop',
#  'desi pop',
#  'desi hip hop',
#  'classic bollywood',
#  'afghan pop',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'filmi',
#  'chutney',
#  'metropopolis',
#  'emo rap',
#  'cloud rap',
#  'filmi',
#  'shanty',
#  'pop',
#  'lo-fi study',
#  'alt z',
#  'chill pop',
#  'filmi',
#  'modern alternative rock',
#  'german soundtrack',
#  'album rock',
#  'glam rock',
#  'brostep',
#  'anime',
#  'disco',
#  'pop',
#  'channel pop',
#  'british singer-songwriter',
#  'alt z',
#  'singer-songwriter pop',
#  'j-pop',
#  'filmi',
#  'filmi',
#  'melodic drill',
#  'easy listening',
#  'atl hip hop',
#  'filmi',
#  'filmi',
#  'indian lo-fi',
#  'desi pop',
#  'detroit hip hop',
#  'modern indie pop',
#  'australian dance',
#  'pop',
#  'alabama indie',
#  'pop',
#  'hip pop',
#  'lo-fi chill',
#  'alternative metal',
#  'dutch house',
#  'pop soul',
#  'desi hip hop',
#  'canadian electronic',
#  'video game music',
#  'comic',
#  'brostep',
#  'eurodance',
#  'emo rap',
#  'dance pop',
#  'k-pop',
#  'irish pop',
#  'brostep',
#  'dutch house',
#  'brostep',
#  'art pop',
#  'alt z',
#  'chillwave',
#  'candy pop',
#  'boy band',
#  'pop',
#  'dance pop',
#  'dutch house',
#  'viral pop',
#  'indie pop rap',
#  'pop',
#  'indie pop rap',
#  'shanty',
#  'neo soul',
#  'pop',
#  'filmi',
#  'filmi',
#  'classic pakistani pop',
#  'classical',
#  'japanese chillhop',
#  'japanese dub',
#  'cloud rap',
#  'video game music',
#  'anime lo-fi',
#  'anime lo-fi',
#  'electra',
#  'social media pop',
#  'acoustic pop',
#  'electro house',
#  'bhangra',
#  'classical',
#  'filmi',
#  'classic pakistani pop',
#  'pop',
#  'acoustic pop',
#  'dutch house',
#  'afrobeats',
#  'filmi',
#  'gregorian dance',
#  'gregorian dance',
#  'electropop',
#  'lo-fi indie',
#  'modern rock',
#  'brostep',
#  'uk contemporary r&b',
#  'desi hip hop',
#  'lo-fi jazzhop',
#  'korean r&b',
#  'australian pop',
#  'ambient folk',
#  'europop',
#  'pop',
#  'pov: indie',
#  'dutch edm',
#  'alternative metal',
#  'filmi',
#  'filmi',
#  'indian indie',
#  'alt z',
#  'pop edm',
#  'chill pop',
#  'classic rock',
#  'glitch hop',
#  'canadian pop',
#  'icelandic indie',
#  'folk-pop',
#  'dance pop',
#  'anime',
#  'ambient pop',
#  'complextro',
#  'piano rock',
#  'alt z',
#  'lo-fi brasileiro',
#  'hip hop',
#  'dutch pop',
#  'chill phonk',
#  'bedroom pop',
#  'classic bollywood',
#  'classic bollywood',
#  'british singer-songwriter',
#  'alt z',
#  'shimmer pop',
#  'desi hip hop',
#  'italian indie pop',
#  'emo rap',
#  'alt z',
#  'anime score',
#  'alt z',
#  'baroque pop',
#  'lo-fi jazzhop',
#  'australian pop',
#  'pop',
#  'alt z',
#  'canadian pop',
#  'indie anthem-folk',
#  'orchestral soundtrack',
#  'filmi',
#  'detroit hip hop',
#  'alt z',
#  'pov: indie',
#  'lo-fi latino',
#  'japanese dub',
#  'bedroom soul',
#  'bedroom soul',
#  'lo-fi study',
#  'lo-fi study',
#  'anime lo-fi',
#  'folk-pop',
#  'german soundtrack',
#  'anime score',
#  'pop',
#  'dancefloor dnb',
#  'anime lo-fi',
#  'nordic house',
#  'singer-songwriter pop',
#  'j-pop',
#  'lo-fi chill',
#  'pakistani pop',
#  'new french touch',
#  'desi pop',
#  'dark r&b',
#  'dark r&b',
#  'pop rap',
#  'glitch hop',
#  'anime score',
#  'anime',
#  'folk-pop',
#  'boy band',
#  'vapor twitch',
#  'traprun',
#  'drift phonk',
#  'drift phonk',
#  'dark trap',
#  'chill phonk',
#  'big room',
#  'josei rap',
#  'pop',
#  'super eurobeat',
#  'drift phonk',
#  'anime',
#  'k-pop',
#  'anime score',
#  'anime score',
#  'anime score',
#  'alternative metal',
#  'pop rap',
#  'desi hip hop',
#  'desi hip hop',
#  'filmi',
#  'desi pop',
#  'album rock',
#  'album rock',
#  'contemporary country',
#  'album rock',
#  'stutter house',
#  'edm',
#  'sad lo-fi',
#  'australian rock',
#  'uk dance',
#  'indie pop rap',
#  'conscious hip hop',
#  'alt z',
#  'singer-songwriter pop',
#  'chill pop',
#  'k-pop',
#  'eurodance',
#  'minneapolis indie',
#  'alt z',
#  'pop',
#  'pop',
#  'afrofuturism',
#  'pop',
#  'alabama indie',
#  'pov: indie',
#  'britcore',
#  'art pop',
#  'pop',
#  'french hip hop',
#  'classic bollywood',
#  'filmi',
#  'leeds indie',
#  'classic bollywood',
#  'minimal tech house',
#  'dance pop',
#  'dance pop',
#  'filmi',
#  'chill out',
#  'denpa-kei',
#  'gaming edm',
#  'brazilian house',
#  'modern rock',
#  'brostep',
#  'filmi',
#  'desi pop',
#  'hands up',
#  'album rock',
#  'anime score',
#  'indian indie',
#  'anime score',
#  'australian pop',
#  'bass trap',
#  'nu disco',
#  'alabama indie',
#  'modern alternative rock',
#  'chamber pop',
#  'electropop',
#  'lo-fi jazzhop',
#  'modern alternative rock',
#  'edm',
#  'k-pop',
#  'detroit hip hop',
#  'aussietronica',
#  'edm',
#  'australian rock',
#  'dance pop',
#  'sleep',
#  'pop',
#  'complextro',
#  'dark r&b',
#  'punjabi pop',
#  'icelandic indie',
#  'mandopop',
#  'alt z',
#  'gen z singer-songwriter',
#  'filmi',
#  'pop',
#  'indie rock italiano',
#  'alternative metal',
#  'alternative r&b',
#  'pop',
#  'alt z',
#  'blues rock',
#  'alaska indie',
#  'estonian electronic',
#  'singer-songwriter pop',
#  'modern rock',
#  'bedroom pop',
#  'boy band',
#  'pop',
#  'bass trap',
#  'folk-pop',
#  'scandipop',
#  'brostep',
#  'post-teen pop',
#  'pop',
#  'hip pop',
#  'pop',
#  'alternative rock',
#  'desi hip hop',
#  'lo-fi study',
#  'filmi',
#  'filmi',
#  'classic bollywood',
#  'bossbeat',
#  'filmi',
#  'baroque pop',
#  'boy band',
#  'metropopolis',
#  'romanian pop',
#  'pop',
#  'r&b',
#  'pop',
#  'alt z',
#  'lo-fi beats',
#  'pop rap',
#  'alt z',
#  'antiviral pop',
#  'belgian edm',
#  'k-pop',
#  'german soundtrack',
#  'chutney',
#  'anime',
#  'baroque',
#  'filmi',
#  'filmi',
#  'classic pakistani pop',
#  'j-pop',
#  'indie game soundtrack',
#  'filmi',
#  'filmi',
#  'filmi',
#  'irish rock',
#  'alternative metal',
#  'alternative metal',
#  'alternative metal',
#  'modern indie pop',
#  'modern alternative pop',
#  'japanese alternative pop',
#  'indie pop',
#  'singer-songwriter pop',
#  'alt z',
#  'j-pop',
#  'rage rap',
#  'nyc pop',
#  'hyperpop',
#  'glitchcore',
#  'alt z',
#  'instrumental grime',
#  'alt z',
#  'pop',
#  'alt z',
#  'bedroom r&b',
#  'sad lo-fi',
#  'alt z',
#  'russian drain',
#  'glitchcore',
#  'alt z',
#  'pop',
#  'alt z',
#  'pop',
#  'alt z',
#  'emo rap',
#  'glitchcore',
#  'emo rap',
#  'alt z',
#  'bedroom soul',
#  'dark r&b',
#  'singer-songwriter pop',
#  'pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'singer-songwriter pop',
#  'pop',
#  'cloud rap',
#  'pop',
#  'bedroom soul',
#  'lo-fi brasileiro',
#  'gen z singer-songwriter',
#  'ambient guitar',
#  'lo-fi chill',
#  'pop',
#  'bedroom soul',
#  'lo-fi chill',
#  'pop',
#  'chill pop',
#  'alt z',
#  'lo-fi study',
#  'gen z singer-songwriter',
#  'alt z',
#  'lo-fi sleep',
#  'indie poptimism',
#  'singer-songwriter pop',
#  'la pop',
#  'broadway',
#  'bedroom r&b',
#  'pop',
#  'singaporean pop',
#  'sad lo-fi',
#  'pop',
#  'glitchcore',
#  'modern rock',
#  'social media pop',
#  'pop',
#  'pop',
#  'j-poprock',
#  'alt z',
#  'pop',
#  'pop',
#  'pop',
#  'pop',
#  'desi pop',
#  'nyc pop',
#  'chill pop',
#  'aesthetic rap',
#  'bedroom r&b',
#  'anime lo-fi',
#  'pop',
#  'glitchcore',
#  'indie poptimism',
#  'chill r&b',
#  'modern indie pop',
#  'ambient folk',
#  'la pop',
#  'pop',
#  'canadian hip hop',
#  'bedroom r&b',
#  'alt z',
#  'alt z',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'la pop',
#  'alt z',
#  'lo-fi brasileiro',
#  'alt z',
#  'alt z',
#  'alternative hip hop',
#  'hip hop',
#  'british indie rock',
#  'alt z',
#  'sad lo-fi',
#  'sad lo-fi',
#  'anime lo-fi',
#  'emo rap',
#  'pop',
#  'pop',
#  'lo-fi chill',
#  'lo-fi sleep',
#  'pop',
#  'gen z singer-songwriter',
#  'pop',
#  'alt z',
#  'modern indie pop',
#  'indie poptimism',
#  'modern indie pop',
#  'alt z',
#  'pop',
#  'turkish edm',
#  'mandopop',
#  'pop',
#  'singer-songwriter pop',
#  'pop',
#  'viral pop',
#  'la pop',
#  'lo-fi study',
#  'modern indie pop',
#  'alt z',
#  'la pop',
#  'singer-songwriter pop',
#  'alt z',
#  'pop',
#  'pop',
#  'lo-fi chill',
#  'gen z singer-songwriter',
#  'la pop',
#  'alt z',
#  'alt z',
#  'modern indie pop',
#  'modern indie pop',
#  'lo-fi chill',
#  'pop edm',
#  'pop edm',
#  'alt z',
#  'pop',
#  'emo rap',
#  'lo-fi chill',
#  'alt z',
#  'social media pop',
#  'dark r&b',
#  'dance pop',
#  'singer-songwriter pop',
#  'indie pop',
#  'lo-fi chill',
#  'alt z',
#  'glitchcore',
#  'modern indie pop',
#  'glitchcore',
#  'modern indie pop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'sad lo-fi',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'singer-songwriter pop',
#  'traprun',
#  'chillhop',
#  'sad rap',
#  'alt z',
#  'alt z',
#  'alt z',
#  'pop',
#  'alt z',
#  'nightcore',
#  'classic texas country',
#  'glitchcore',
#  'japanese alternative pop',
#  'social media pop',
#  'ukrainian viral pop',
#  'indie electropop',
#  'abstract beats',
#  'anime lo-fi',
#  'desi pop',
#  'social media pop',
#  'glitchcore',
#  'singer-songwriter pop',
#  'alt z',
#  'japanese chillhop',
#  'canadian hip hop',
#  'alt z',
#  'sad rap',
#  'la pop',
#  'anime lo-fi',
#  'hyperpop',
#  'alt z',
#  'art pop',
#  'indonesian r&b',
#  'canadian electronic',
#  'conscious hip hop',
#  'indie anthem-folk',
#  'ohio hip hop',
#  'la pop',
#  'glitchcore',
#  'pop',
#  'j-pop',
#  'modern indie pop',
#  'lo-fi chill',
#  'alt z',
#  'sped up',
#  'pop',
#  'modern indie pop',
#  'nyc pop',
#  'indie pop',
#  'chill r&b',
#  'lo-fi study',
#  'pop',
#  'ohio hip hop',
#  'pop',
#  'pop',
#  'pop',
#  'alt z',
#  'la pop',
#  'anime lo-fi',
#  'bedroom soul',
#  'bedroom pop',
#  'la pop',
#  'lo-fi beats',
#  'hyperpop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'modern indie pop',
#  'lo-fi sleep',
#  'chicago rap',
#  'pop',
#  'instrumental math rock',
#  'pop',
#  'glitchcore',
#  'alt z',
#  'pop',
#  'lo-fi sleep',
#  'anime lo-fi',
#  'glitchcore',
#  'sped up',
#  'lo-fi chill',
#  'la pop',
#  'pop',
#  'alt z',
#  'pop',
#  'singer-songwriter pop',
#  'dfw rap',
#  'glitchcore',
#  'pittsburgh rap',
#  'alt z',
#  'alt z',
#  'lo-fi chill',
#  'lo-fi chill',
#  'alt z',
#  'bedroom r&b',
#  'post-teen pop',
#  'lo-fi cover',
#  'chillhop',
#  'chill pop',
#  'pop',
#  'bedroom soul',
#  'bedroom soul',
#  'alt z',
#  'pop',
#  'alt z',
#  'lo-fi sleep',
#  'sad lo-fi',
#  'pop',
#  'lo-fi chill',
#  'alt z',
#  'chill pop',
#  'hyperpop',
#  'glitchcore',
#  'bedroom soul',
#  'lo-fi chill',
#  'glitchcore',
#  'alt z',
#  'colombian pop',
#  'alt z',
#  'pop',
#  'pop',
#  'pop',
#  'sad lo-fi',
#  'lo-fi sleep',
#  'alt z',
#  'alt z',
#  'modern indie pop',
#  'modern indie pop',
#  'modern indie pop',
#  'bedroom r&b',
#  'lo-fi beats',
#  'alt z',
#  'alt z',
#  'canadian hip hop',
#  'pop',
#  'drift phonk',
#  'pop',
#  'alt z',
#  'singer-songwriter pop',
#  'la pop',
#  'drift phonk',
#  'drift phonk',
#  'french pop',
#  'lo-fi chill',
#  'glitchcore',
#  'emo rap',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'gen z singer-songwriter',
#  'bedroom r&b',
#  'art pop',
#  'alt z',
#  'lo-fi chill',
#  'gen z singer-songwriter',
#  'pop',
#  'pop',
#  'lo-fi cover',
#  'alt z',
#  'alt z',
#  'emo rap',
#  'la pop',
#  'alt z',
#  'alt z',
#  'alt z',
#  'alt z',
#  'focus beats',
#  'gym phonk',
#  'lo-fi sleep',
#  'nuevo folklore mexicano',
#  'hard bass',
#  'classical',
#  'russian pop',
#  'israeli mediterranean',
#  'israeli pop',
#  'israeli mediterranean',
#  'thai indie rock',
#  'j-pop',
#  'anime',
#  'j-rock',
#  'denpa-kei',
#  'anime',
#  'j-pop',
#  'j-pop',
#  'anime',
#  'japanese dance pop',
#  'anime',
#  'anime',
#  'anime',
#  'anime score',
#  'anime',
#  'classical',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'anime',
#  'chinese viral pop',
#  'japanese teen pop',
#  'anime',
#  'anime',
#  'j-pop',
#  'anime',
#  'japanese alternative rock',
#  'anime rock',
#  'anime',
#  'japanese teen pop',
#  'japanese teen pop',
#  'anime',
#  'anime',
#  'j-pop',
#  'anime',
#  'pop',
#  'la pop',
#  'uk pop',
#  'detroit hip hop',
#  'indietronica',
#  'alternative dance',
#  'ambient pop',
#  'sad rap',
#  'disco',
#  'alternative metal',
#  'alt z',
#  'canadian contemporary r&b',
#  'cloud rap',
#  'indie electropop',
#  'lo-fi indie',
#  'chillwave',
#  'edm',
#  'cloud rap',
#  'indie electropop',
#  'chillstep',
#  'chillwave',
#  'japanese chillhop',
#  'anime rock',
#  'pop',
#  'modern alternative rock',
#  'eurodance',
#  'anime lo-fi',
#  'anime lo-fi',
#  'chillhop',
#  'filmi',
#  'electra',
#  'viral pop',
#  'melodic rap',
#  'modern indie folk',
#  'chill phonk',
#  'social media pop',
#  'alternative metal',
#  'pop',
#  'la pop',
#  'afghan pop',
#  'desi hip hop',
#  'art pop',
#  'indie electropop',
#  'modern rock',
#  'icelandic indie',
#  'chanson',
#  'modern alternative rock',
#  'disco',
#  'bubblegum dance',
#  'contemporary country',
#  'art pop',
#  'death metal',
#  'indie pop',
#  'british singer-songwriter',
#  'singer-songwriter pop',
#  'dance pop',
#  'modern rock',
#  'chicago rap',
#  'alternative dance',
#  'alt z',
#  'k-pop',
#  'pop',
#  'canadian pop',
#  'alt z',
#  'detroit hip hop',
#  'vocal trance',
#  'dance pop',
#  'alt z',
#  'neo mellow',
#  'german dance',
#  'alternative metal',
#  'album rock',
#  'brostep',
#  'pop edm',
#  'canadian electronic',
#  'icelandic indie',
#  'aussietronica',
#  'indie rock',
#  'indie rockism',
#  'lo-fi study',
#  'pop edm',
#  'melodic dubstep',
#  'lo-fi study',
#  'boy band',
#  'swedish singer-songwriter',
#  'cloud rap',
#  'cloud rap',
#  'persian pop',
#  'canadian electronic',
#  'chill pop',
#  'edm',
#  'singer-songwriter pop',
#  'ccm',
#  'alternative rock',
#  'desi hip hop',
#  'baroque pop',
#  'anime',
#  'anime',
#  'anime',
#  'metropopolis',
#  'folk-pop',
#  'modern alternative pop',
#  'solipsynthm',
#  'shanty',
#  'meme',
#  'filmi',
#  'funk carioca',
#  'trap queen',
#  'sad lo-fi',
#  'future bass',
#  'j-pop',
#  'indietronica',
#  'alternative metal',
#  'downtempo',
#  'gen z singer-songwriter',
#  'new french touch',
#  'norwegian pop',
#  'alternative metal',
#  'deep underground hip hop',
#  'singer-songwriter pop',
#  'viral pop',
#  'modern rock',
#  'acoustic pop',
#  'japanese chillhop',
#  'swiss pop',
#  'cloud rap',
#  'future bass',
#  'alternative metal',
#  'anime lo-fi',
#  'anime lo-fi',
#  'gen z singer-songwriter',
#  'anime',
#  'slowed and reverb',
#  'downtempo',
#  'east coast hip hop',
#  'meme rap',
#  'alternative metal',
#  'pop',
#  'electropop',
#  'alt z',
#  'dark trap',
#  'dark r&b',
#  'canadian contemporary r&b',
#  'drift phonk',
#  'drift phonk',
#  'drift phonk',
#  'gym phonk',
#  'indiecoustica',
#  'chamber psych',
#  'j-pop',
#  ...]

# %%
pca_with_genre2.head()
# Out:
#                             PCA1      PCA2
# genre
# alt z                   4.387375 -2.479845
# dance pop             -25.564251  0.132000
# singer-songwriter pop  23.339888 -3.261445
# singer-songwriter pop  23.296996 -2.983431
# alt z                 -23.604580 -1.587518

# %%
pca_with_genre.head()
# Out:
#                         PCA1      PCA2
# genre
# british orchestra -13.020522 -4.354974
# glitchcore         -1.780848  1.286125
# experimental pop   -5.707595  2.975120
# album rock        -38.401718 -1.353992
# alt z               0.984533 -3.926671

# %%
pca_with_genre2.reset_index(inplace=True)

# %%
pca_with_genre.reset_index(inplace=True)

# %%
pca_with_genre2.dropna(inplace=True)

# %%
pca_with_genre.dropna(inplace=True)

# %%
pca_with_genre2.set_index('genre', inplace=True)

# %%
pca_with_genre.set_index('genre', inplace=True)

# %%
pca_with_genre2.head()
# Out:
#                             PCA1      PCA2
# genre
# alt z                   4.387375 -2.479845
# dance pop             -25.564251  0.132000
# singer-songwriter pop  23.339888 -3.261445
# singer-songwriter pop  23.296996 -2.983431
# alt z                 -23.604580 -1.587518

# %%
pca_with_genre.head()
# Out:
#                         PCA1      PCA2
# genre
# british orchestra -13.020522 -4.354974
# glitchcore         -1.780848  1.286125
# experimental pop   -5.707595  2.975120
# album rock        -38.401718 -1.353992
# alt z               0.984533 -3.926671

# %%
# elbow method with pca

# Create a a list to store inertia values and the values of k
inertia = []
k = list(range(1, 11))

# Append the value of the computed inertia from the `inertia_` attribute of teh KMeans model instance
for i in k:
    k_model = KMeans(n_clusters=i, random_state=42)
    k_model.fit(pca_with_genre2)
    inertia.append(k_model.inertia_)

# Define a DataFrame to hold the values for k and the corresponding inertia
elbow_data = {"k": k, "inertia": inertia}
df_elbow2 = pd.DataFrame(elbow_data)

# Review the DataFrame
df_elbow2.head()
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#    k        inertia
# 0  1  818093.738576
# 1  2  312008.888462
# 2  3  163486.890496
# 3  4  112830.953307
# 4  5   78562.550732

# %%
# elbow method with pca

# Create a a list to store inertia values and the values of k
inertia = []
k = list(range(1, 11))

# Append the value of the computed inertia from the `inertia_` attribute of teh KMeans model instance
for i in k:
    k_model = KMeans(n_clusters=i, random_state=42)
    k_model.fit(pca_with_genre)
    inertia.append(k_model.inertia_)

# Define a DataFrame to hold the values for k and the corresponding inertia
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

# Review the DataFrame
df_elbow.head()
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#    k       inertia
# 0  1  6.326776e+06
# 1  2  2.344691e+06
# 2  3  1.195858e+06
# 3  4  8.302207e+05
# 4  5  5.892958e+05

# %%
 # Plot the Elbow Curve
df_elbow2.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %%
 # Plot the Elbow Curve
df_elbow.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
# Out:
# :Curve   [k]   (inertia)

# %%
# Define the model with 3 clusters
model = KMeans(n_clusters=3, random_state=42)

# Fit the model
model.fit(pca_with_genre2)

# Make predictions
k_3_2= model.predict(pca_with_genre2)

# Create a copy of the PCA DataFrame
song_pca_predictions_df2 = pca_with_genre2.copy()

# Add a class column with the labels
song_pca_predictions_df2["predictions"] = k_3_2
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Define the model with 3 clusters
model = KMeans(n_clusters=3, random_state=42)

# Fit the model
model.fit(pca_with_genre)

# Make predictions
k_3 = model.predict(pca_with_genre)

# Create a copy of the PCA DataFrame
song_pca_predictions_df = pca_with_genre.copy()

# Add a class column with the labels
song_pca_predictions_df["predictions"] = k_3
# Out:
# c:\Users\Owner\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Plot the clusters
song_pca_predictions_df2.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="predictions",
    hover_cols=['genre'],
    title='pca'
)
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PCA1]   (PCA2,genre)

# %%
# Plot the clusters
song_pca_predictions_df.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="predictions"
)
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PCA1]   (PCA2)

# %%
song_pca_predictions_df.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="predictions",
    hover_cols=['genre'],
    title='pca'
)
# Out:
# :NdOverlay   [predictions]
#    :Scatter   [PCA1]   (PCA2,genre)

# %%
song_pca_predictions_df2.head()
# Out:
#                             PCA1      PCA2  predictions
# genre
# alt z                   4.387375 -2.479845            0
# dance pop             -25.564251  0.132000            1
# singer-songwriter pop  23.339888 -3.261445            2
# singer-songwriter pop  23.296996 -2.983431            2
# alt z                 -23.604580 -1.587518            1

# %%
song_pca_predictions_df.head()
# Out:
#                         PCA1      PCA2  predictions
# genre
# british orchestra -13.020522 -4.354974            0
# glitchcore         -1.780848  1.286125            0
# experimental pop   -5.707595  2.975120            0
# album rock        -38.401718 -1.353992            2
# alt z               0.984533 -3.926671            0
